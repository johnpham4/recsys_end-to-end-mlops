# %% [markdown]
# # Set up

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from qdrant_client import QdrantClient
import os
import sys

sys.path.insert(0, "..")

from pydantic import BaseModel
import torch
from dotenv import load_dotenv
from loguru import logger
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, PointStruct, VectorParams

import mlflow

load_dotenv()
# Out:
# True

# %% [markdown]
# # Controller

# %%
class Args(BaseModel):
    testing: bool = False
    run_name: str = "000-first-attempt"
    notebook_persist_dp: str = None
    random_seed: int = 41
    device: str = None

    top_K: int = 100
    top_k: int = 10

    embedding_dim: int = 128

    mlf_model_name: str = "item2vec"

    batch_recs_fp: str = None

    qdrant_url: str = None
    qdrant_collection_name: str = None

    def init(self):
        self.notebook_persist_dp = os.path.abspath(f"data/{self.run_name}")
        os.makedirs(self.notebook_persist_dp, exist_ok=True)
        self.batch_recs_fp = f"{self.notebook_persist_dp}/batch_recs.jsonl"

        if not (qdrant_host := os.getenv("QDRANT_HOST")):
            raise Exception(f"Environment variable QDRANT_HOST is not set.")

        qdrant_port = os.getenv("QDRANT_PORT")
        self.qdrant_url = f"{qdrant_host}:{qdrant_port}"
        self.qdrant_collection_name = os.getenv("QDRANT_COLLECTION_NAME")

        return self


args = Args().init()

print(args.model_dump_json(indent=2))
# Out:
# {
#   "testing": false,
#   "run_name": "000-first-attempt",
#   "notebook_persist_dp": "/mnt/d/projects/recsys/notebooks/data/000-first-attempt",
#   "random_seed": 41,
#   "device": null,
#   "top_K": 100,
#   "top_k": 10,
#   "embedding_dim": 128,
#   "mlf_model_name": "item2vec",
#   "batch_recs_fp": "/mnt/d/projects/recsys/notebooks/data/000-first-attempt/batch_recs.jsonl",
#   "qdrant_url": "localhost:6333",
#   "qdrant_collection_name": "item2vec"
# }

# %% [markdown]
# # Load Model

# %%
mlf_client = mlflow.MlflowClient()

# %%
model = mlflow.pyfunc.load_model(model_uri=f"models:/{args.mlf_model_name}@champion")
# Out:
# Downloading artifacts:   0%|          | 0/9 [00:00<?, ?it/s]
# /mnt/d/projects/recsys/.venv/lib/python3.11/site-packages/mlflow/pyfunc/utils/data_validation.py:186: UserWarning: Add type hints to the `predict` method to enable data validation and automatic signature inference during model logging. Check https://mlflow.org/docs/latest/model/python_model.html#type-hint-usage-in-pythonmodel for more details.
#   color_warning(

# %%
run_id = model.metadata.run_id
run_info = mlf_client.get_run(run_id).info
artifact_uri = run_info.artifact_uri

# %%
artifact_uri
# Out:
# 'mlflow-artifacts:/1/4b208545a85b433d85b0f61e55e85f16/artifacts'

# %%
sample_input = mlflow.artifacts.load_dict(
    f"models:/{args.mlf_model_name}@champion/input_example.json"
)
sample_input
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# {'item_1_ids': ['0375869026'], 'item_2_ids': ['9625990674']}

# %%
prediction = model.predict(sample_input)
prediction
# Out:
# {'item_1_ids': ['0375869026'],
#  'item_2_ids': ['9625990674'],
#  'scores': [0.4312632381916046]}

# %% [markdown]
# # Get Embedding

# %%
skipgram_model = model.unwrap_python_model().model
embedding_0 = skipgram_model.embeddings(torch.tensor(0))
embedding_dim = embedding_0.size()[0]
embedding_0
# Out:
# tensor([-0.0020, -0.0184,  0.0391,  0.0642,  0.0376,  0.0486,  0.1148,  0.0446,
#         -0.2252,  0.0908, -0.0712,  0.0655,  0.1153,  0.0209,  0.2188, -0.1144,
#         -0.3277,  0.0307, -0.3318, -0.0807,  0.1248,  0.0999,  0.0016, -0.1236,
#          0.0700,  0.2429, -0.1043,  0.0345, -0.1657,  0.1284, -0.2426, -0.0023,
#         -0.0329,  0.0266,  0.1605,  0.1208,  0.0235, -0.0150,  0.0780,  0.0047,
#          0.2346,  0.0712,  0.2373,  0.0247, -0.0358,  0.0112, -0.0911,  0.0224,
#         -0.0531, -0.1322,  0.1567, -0.1460, -0.2184, -0.0824, -0.1033, -0.3565,
#         -0.1095, -0.0798, -0.0802,  0.0030, -0.0210,  0.1618, -0.0508, -0.0799,
#          0.0604, -0.0424, -0.2881, -0.1340,  0.1210,  0.0142, -0.0659,  0.3046,
#          0.0363, -0.1055, -0.2015, -0.0947,  0.0137,  0.0554, -0.0403, -0.3724,
#          0.0957,  0.2741,  0.0576,  0.3932,  0.0308, -0.0980, -0.0256, -0.1675,
#          0.0578, -0.0371, -0.2635,  0.1179, -0.2434,  0.1774,  0.1601,  0.1509,
#         -0.1095,  0.0459, -0.2084,  0.0852,  0.0706,  0.0853,  0.0814,  0.1260,
#          0.1059, -0.0192,  0.0364,  0.0774, -0.0398, -0.0447, -0.1617,  0.1808,
#         -0.1019, -0.0175,  0.1773,  0.0324, -0.1187,  0.0176,  0.2289, -0.1040,
#          0.0751, -0.0779,  0.1740, -0.3110,  0.0202,  0.0790, -0.0441,  0.0825],
#        grad_fn=<EmbeddingBackward0>)

# %%
id_mapping = model.unwrap_python_model().id_mapping
all_items = list(id_mapping["id_to_idx"].values())
all_items[:5]
# Out:
# [0, 1, 2, 3, 4]

# %%
embeddings = skipgram_model.embeddings(torch.tensor(all_items)).detach().numpy()
embeddings
# Out:
# array([[-0.001965  , -0.01844763,  0.0390514 , ...,  0.0789619 ,
#         -0.04411918,  0.08246701],
#        [ 0.01574272, -0.1106883 ,  0.04423822, ...,  0.03968391,
#          0.00295376,  0.03199833],
#        [-0.09473783,  0.11698911,  0.06254044, ..., -0.07346609,
#          0.219918  , -0.26206523],
#        ...,
#        [-0.01189691, -0.16669825, -0.01239961, ..., -0.08236234,
#         -0.00691404,  0.04842342],
#        [-0.03206192, -0.08211985, -0.0188489 , ..., -0.04013699,
#          0.00213255, -0.03188387],
#        [ 0.03446096, -0.00518576, -0.04457873, ..., -0.01205611,
#         -0.04385417, -0.04071712]], dtype=float32)

# %%
embeddings.shape
# Out:
# (4630, 128)

# %% [markdown]
# # Qdrant

# %%
ann_index = QdrantClient(url=args.qdrant_url)

# %%
collection_exists = ann_index.collection_exists(args.qdrant_collection_name)
if collection_exists:
    logger.info(f"Deleting existing Qdrant collection {args.qdrant_collection_name}...")
    ann_index.delete_collection(args.qdrant_collection_name)

create_collection_result = ann_index.create_collection(
    collection_name=args.qdrant_collection_name,
    vectors_config=VectorParams(size=embedding_dim, distance=Distance.COSINE),
)

assert create_collection_result == True

# %%
upsert_result = ann_index.upsert(
    collection_name=args.qdrant_collection_name,
    points=[
        PointStruct(id=idx, vector=vector.tolist(), payload={})
        for idx, vector in enumerate(embeddings)
    ],
)
assert str(upsert_result.status) == "completed"
upsert_result
# Out:
# UpdateResult(operation_id=0, status=<UpdateStatus.COMPLETED: 'completed'>)

# %%
hits = ann_index.search(
    collection_name=args.qdrant_collection_name,
    query_vector=embeddings[0],
    limit=args.top_K,
)

# %%
hits
# Out:
# [ScoredPoint(id=0, version=0, score=0.9999999, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=4306, version=0, score=0.39393944, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3263, version=0, score=0.3846603, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3335, version=0, score=0.3804885, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2586, version=0, score=0.37781808, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2496, version=0, score=0.3719725, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=4226, version=0, score=0.36930364, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2520, version=0, score=0.3658317, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2453, version=0, score=0.36191103, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2625, version=0, score=0.3584263, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3094, version=0, score=0.35784498, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3006, version=0, score=0.3512297, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=1223, version=0, score=0.351199, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2959, version=0, score=0.35044557, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=4322, version=0, score=0.34996647, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3631, version=0, score=0.34932655, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2741, version=0, score=0.34912688, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2074, version=0, score=0.34811276, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3330, version=0, score=0.34707388, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3905, version=0, score=0.3453367, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=4430, version=0, score=0.34452683, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=4194, version=0, score=0.341504, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3240, version=0, score=0.33608466, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2729, version=0, score=0.33582017, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2684, version=0, score=0.33494318, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=4346, version=0, score=0.331421, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3108, version=0, score=0.3304948, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2828, version=0, score=0.32606676, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3104, version=0, score=0.32543778, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=4094, version=0, score=0.32478333, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3878, version=0, score=0.32370022, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3051, version=0, score=0.3228008, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2934, version=0, score=0.321292, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=760, version=0, score=0.3178127, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=4000, version=0, score=0.31738347, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=4157, version=0, score=0.31242564, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3745, version=0, score=0.31119505, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3733, version=0, score=0.31074244, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3784, version=0, score=0.3104815, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=4280, version=0, score=0.30994943, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2978, version=0, score=0.3097436, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2961, version=0, score=0.30630317, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3589, version=0, score=0.30616117, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=1960, version=0, score=0.30578735, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2411, version=0, score=0.30347884, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3760, version=0, score=0.30276176, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3195, version=0, score=0.30148777, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2479, version=0, score=0.30143967, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2660, version=0, score=0.301355, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3178, version=0, score=0.30090237, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3115, version=0, score=0.29573315, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2901, version=0, score=0.29345024, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2709, version=0, score=0.29124516, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3940, version=0, score=0.2907168, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3598, version=0, score=0.29017267, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3234, version=0, score=0.28939763, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=4244, version=0, score=0.28825843, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2944, version=0, score=0.2880693, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3552, version=0, score=0.28792655, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=1575, version=0, score=0.2873823, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3370, version=0, score=0.28728342, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=4395, version=0, score=0.28604832, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3200, version=0, score=0.2859465, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=1458, version=0, score=0.28592414, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3423, version=0, score=0.28587973, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=4142, version=0, score=0.285144, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=4543, version=0, score=0.28356326, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2412, version=0, score=0.28331077, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=4515, version=0, score=0.2831421, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2827, version=0, score=0.28266984, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=4080, version=0, score=0.2813272, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2132, version=0, score=0.28012714, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=1657, version=0, score=0.27986565, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3068, version=0, score=0.27970713, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=4603, version=0, score=0.2796504, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3073, version=0, score=0.2795598, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3157, version=0, score=0.27949187, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3728, version=0, score=0.27843466, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2097, version=0, score=0.27774876, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2666, version=0, score=0.27736816, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2523, version=0, score=0.27674106, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2706, version=0, score=0.2754215, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=1874, version=0, score=0.27464432, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=1668, version=0, score=0.27399123, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2758, version=0, score=0.2736608, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2765, version=0, score=0.27322984, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=542, version=0, score=0.27246585, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3639, version=0, score=0.27208334, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=4256, version=0, score=0.2711967, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2652, version=0, score=0.2707782, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=1793, version=0, score=0.2704801, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2252, version=0, score=0.2697971, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2831, version=0, score=0.26979557, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3319, version=0, score=0.26966637, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=2372, version=0, score=0.26964158, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=4117, version=0, score=0.26870674, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=4611, version=0, score=0.26866648, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3004, version=0, score=0.26861697, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3977, version=0, score=0.2685598, payload={}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=3447, version=0, score=0.2677914, payload={}, vector=None, shard_key=None, order_value=None)]
