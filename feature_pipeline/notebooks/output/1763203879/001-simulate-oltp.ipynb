# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [14]</a>'.</span>

# %% [markdown]
# # Set up

# %%
import os
import sys

import datasets
import pandas as pd
from datasets import load_dataset
from dotenv import load_dotenv
from loguru import logger
from pydantic import BaseModel
from sqlalchemy import create_engine

sys.path.insert(0, "..")
sys.path.insert(1, "../../")

from src.utils import handle_dtypes, parse_dt
from src.init_s3 import init_s3_client

load_dotenv("../../.env")
datasets.logging.set_verbosity_error()

# %% [markdown]
# # Controller

# %%
class Args(BaseModel):
    run_name: str = "000-prep-data"
    testing: bool = True
    notebook_persist_dp: str = None
    random_seed: int = 41

    train_fp: str = "../../data/train.parquet"
    val_fp: str = "../../data/val.parquet"

    user_col: str = "user_id"
    item_col: str = "parent_asin"
    rating_col: str = "rating"
    timestamp_col: str = "timestamp"

    # Number of days left out not being pushed into the OLTP so that later we can simulate having them as new data
    num_days_holdout: int = 30
    holdout_fp: str = "../../data/holdout.parquet"

    # Output PostgreSQL table
    table_name: str = "amz_review_rating_raw"

    def init(self):
        self.notebook_persist_dp = os.path.abspath(f"data/{self.run_name}")
        if not self.testing:
            os.makedirs(self.notebook_persist_dp, exist_ok=True)

        return self


args = Args().init()

print(args.model_dump_json(indent=2))
# Out:
# {
#   "run_name": "000-prep-data",
#   "testing": true,
#   "notebook_persist_dp": "/mnt/d/projects/recsys/backend/feature_pipeline/notebooks/data/000-prep-data",
#   "random_seed": 41,
#   "train_fp": "../../data/train.parquet",
#   "val_fp": "../../data/val.parquet",
#   "user_col": "user_id",
#   "item_col": "parent_asin",
#   "rating_col": "rating",
#   "timestamp_col": "timestamp",
#   "num_days_holdout": 30,
#   "holdout_fp": "../../data/holdout.parquet",
#   "table_name": "amz_review_rating_raw"
# }

# %% [markdown]
# # Load Data

# %%
metadata_raw = load_dataset(
    "McAuley-Lab/Amazon-Reviews-2023", "raw_meta_Video_Games", trust_remote_code=True
)
metadata_raw_df = metadata_raw["full"].to_pandas()
metadata_raw_df
# Out:
#                     main_category  \
# 0                     Video Games
# 1                     Video Games
# 2                     Video Games
# 3                     Video Games
# 4                     Video Games
# ...                           ...
# 137264                       None
# 137265                Video Games
# 137266  Cell Phones & Accessories
# 137267                       None
# 137268                       None
#
#                                                     title  average_rating  \
# 0                          Dash 8-300 Professional Add-On             5.0
# 1                       Phantasmagoria: A Puzzle of Flesh             4.1
# 2        NBA 2K17 - Early Tip Off Edition - PlayStation 4             4.3
# 3       Nintendo Selects: The Legend of Zelda Ocarina ...             4.9
# 4        Thrustmaster Elite Fitness Pack for Nintendo Wii             3.0
# ...                                                   ...             ...
# 137264  Story of Seasons: Pioneers Of Olive Town (Nint...             4.5
# 137265           MotoGP 18 (PC DVD) UK IMPORT REGION FREE             4.0
# 137266  Century Accessory Soft Silicone Protective Ski...             2.9
# 137267  Hasbro Interactive Mr. Potato Head Activity Pa...             3.9
# 137268                                  Worms: Armageddon             4.3
#
#         rating_number                                           features  \
# 0                   1  [Features Dash 8-300 and 8-Q300 ('Q' rollout l...
# 1                  18                                       [Windows 95]
# 2                 223  [The #1 rated NBA video game simulation series...
# 3                  22  [Authentic Nintendo Selects: The Legend of Zel...
# 4                   3  [Includes (9) Total Accessories, Pedometer, Wi...
# ...               ...                                                ...
# 137264            397  [A wild world of discovery - tame the wilderne...
# 137265              1  [Brand new game engine - MotoGP18 has been reb...
# 137266             19  [Easy access to all buttons, controls and port...
# 137267              5                                                 []
# 137268             13                                                 []
#
#                                               description  price  \
# 0       [The Dash 8-300 Professional Add-On lets you p...   None
# 1                                                      []   None
# 2       [Following the record-breaking launch of NBA 2...   58.0
# 3                                                      []  37.42
# 4       [The Thrustmaster Motion Plus Elite Fitness Pa...   None
# ...                                                   ...    ...
# 137264  [Product Description, Inspired by Tales of you...  31.04
# 137265  [Become the champion of the 2018 MotoGP Season...   None
# 137266  [This soft case cover will add a splash of col...   None
# 137267  [Amazon.com, Everyone's favorite master-of-dis...   None
# 137268  [Product Description, Do you ever wonder what ...   None
#
#                                                    images  \
# 0       {'hi_res': [None], 'large': ['https://m.media-...
# 1       {'hi_res': ['https://m.media-amazon.com/images...
# 2       {'hi_res': ['https://m.media-amazon.com/images...
# 3       {'hi_res': ['https://m.media-amazon.com/images...
# 4       {'hi_res': [None, None, None, None, None, None...
# ...                                                   ...
# 137264  {'hi_res': ['https://m.media-amazon.com/images...
# 137265  {'hi_res': ['https://m.media-amazon.com/images...
# 137266  {'hi_res': ['https://m.media-amazon.com/images...
# 137267  {'hi_res': [None, 'https://m.media-amazon.com/...
# 137268  {'hi_res': ['https://m.media-amazon.com/images...
#
#                                                    videos              store  \
# 0                 {'title': [], 'url': [], 'user_id': []}           Aerosoft
# 1                 {'title': [], 'url': [], 'user_id': []}             Sierra
# 2       {'title': ['NBA 2K17 - Kobe: Haters vs Players...                 2K
# 3                 {'title': [], 'url': [], 'user_id': []}     Amazon Renewed
# 4                 {'title': [], 'url': [], 'user_id': []}       THRUSTMASTER
# ...                                                   ...                ...
# 137264            {'title': [], 'url': [], 'user_id': []}   Marvelous Europe
# 137265            {'title': [], 'url': [], 'user_id': []}          Milestone
# 137266            {'title': [], 'url': [], 'user_id': []}  Century Accessory
# 137267            {'title': [], 'url': [], 'user_id': []}             Hasbro
# 137268            {'title': [], 'url': [], 'user_id': []}             Hasbro
#
#                                                categories  \
# 0                                [Video Games, PC, Games]
# 1                                [Video Games, PC, Games]
# 2                     [Video Games, PlayStation 4, Games]
# 3       [Video Games, Legacy Systems, Nintendo Systems...
# 4       [Video Games, Legacy Systems, Nintendo Systems...
# ...                                                   ...
# 137264              [Video Games, Nintendo Switch, Games]
# 137265             [Video Games, Game Genre of the Month]
# 137266  [Video Games, Legacy Systems, Xbox Systems, Xb...
# 137267                           [Video Games, PC, Games]
# 137268  [Video Games, Legacy Systems, Sega Systems, Se...
#
#                                                   details parent_asin  \
# 0       {"Pricing": "The strikethrough price is the Li...  B000FH0MHO
# 1       {"Best Sellers Rank": {"Video Games": 137612, ...  B00069EVOG
# 2       {"Release date": "September 16, 2016", "Best S...  B00Z9TLVK0
# 3       {"Best Sellers Rank": {"Video Games": 51019, "...  B07SZJZV88
# 4       {"Release date": "November 1, 2009", "Pricing"...  B002WH4ZJG
# ...                                                   ...         ...
# 137264  {"Release date": "March 26, 2021", "Best Selle...  B09XQJS4CZ
# 137265  {"Pricing": "The strikethrough price is the Li...  B07DGPTGNV
# 137266  {"Package Dimensions": "2.76 x 2.76 x 0.2 inch...  B00HUWCQBW
# 137267  {"Release date": "July 24, 1999", "Best Seller...  B00002S9MH
# 137268  {"Release date": "December 3, 1999", "Best Sel...  B00001OX4N
#
#        bought_together subtitle author
# 0                 None     None   None
# 1                 None     None   None
# 2                 None     None   None
# 3                 None     None   None
# 4                 None     None   None
# ...                ...      ...    ...
# 137264            None     None   None
# 137265            None     None   None
# 137266            None     None   None
# 137267            None     None   None
# 137268            None     None   None
#
# [137269 rows x 16 columns]

# %%
if not os.path.exists(args.train_fp):
    raise Exception(
        f"{args.train_fp} does not exist, you need to run the notebook 000-prep-data in the parent recsys-mvp folder first"
    )

train_df = pd.read_parquet(args.train_fp)
val_df = pd.read_parquet(args.val_fp)

# %%
train_df
# Out:
#                              user_id parent_asin  rating      timestamp
# 54      AHATA6X6MYTC3VNBFJ3WIYVK257A  B0050SVNZ8     4.0  1321885664000
# 55      AHATA6X6MYTC3VNBFJ3WIYVK257A  B00LZVNWIA     4.0  1408233606000
# 61      AHATA6X6MYTC3VNBFJ3WIYVK257A  B0BH98D8GL     5.0  1511708554100
# 62      AHATA6X6MYTC3VNBFJ3WIYVK257A  B074RNL1RX     5.0  1511753174174
# 63      AHATA6X6MYTC3VNBFJ3WIYVK257A  B089QYP649     5.0  1531092820696
# ...                              ...         ...     ...            ...
# 736763  AE3P3SRQSH7R4R7RR2KMUEWLEXPQ  B004IWRNTC     5.0  1394472136000
# 736764  AE3P3SRQSH7R4R7RR2KMUEWLEXPQ  B01FSKACPY     5.0  1394472165000
# 736765  AE3P3SRQSH7R4R7RR2KMUEWLEXPQ  B002JTX9WQ     5.0  1394472180000
# 736767  AE3P3SRQSH7R4R7RR2KMUEWLEXPQ  B0017QFMJU     5.0  1394472206000
# 736769  AE3P3SRQSH7R4R7RR2KMUEWLEXPQ  B00DB2BI8M     5.0  1394472359000
#
# [164298 rows x 4 columns]

# %% [markdown]
# # Merge metadata

# %%
cols = ["main_category", "title", "description", "categories", "price"]

train_features_df = pd.merge(
    train_df, metadata_raw_df[[args.item_col] + cols + ["images"]], how="left", on=args.item_col
)
val_features_df = pd.merge(
    val_df, metadata_raw_df[[args.item_col] + cols + ["images"]], how="left", on=args.item_col
)
train_features_df
# Out:
#                              user_id parent_asin  rating      timestamp  \
# 0       AHATA6X6MYTC3VNBFJ3WIYVK257A  B0050SVNZ8     4.0  1321885664000
# 1       AHATA6X6MYTC3VNBFJ3WIYVK257A  B00LZVNWIA     4.0  1408233606000
# 2       AHATA6X6MYTC3VNBFJ3WIYVK257A  B0BH98D8GL     5.0  1511708554100
# 3       AHATA6X6MYTC3VNBFJ3WIYVK257A  B074RNL1RX     5.0  1511753174174
# 4       AHATA6X6MYTC3VNBFJ3WIYVK257A  B089QYP649     5.0  1531092820696
# ...                              ...         ...     ...            ...
# 164293  AE3P3SRQSH7R4R7RR2KMUEWLEXPQ  B004IWRNTC     5.0  1394472136000
# 164294  AE3P3SRQSH7R4R7RR2KMUEWLEXPQ  B01FSKACPY     5.0  1394472165000
# 164295  AE3P3SRQSH7R4R7RR2KMUEWLEXPQ  B002JTX9WQ     5.0  1394472180000
# 164296  AE3P3SRQSH7R4R7RR2KMUEWLEXPQ  B0017QFMJU     5.0  1394472206000
# 164297  AE3P3SRQSH7R4R7RR2KMUEWLEXPQ  B00DB2BI8M     5.0  1394472359000
#
#        main_category                                              title  \
# 0        Video Games  Amazon Basics Carrying Case for Nintendo - New...
# 1          Computers       Logitech G402 Hyperion Fury FPS Gaming Mouse
# 2          Computers  Logitech G433 7.1 Wired Gaming Headset with DT...
# 3        Video Games  Razer Wolverine Ultimate Officially Licensed X...
# 4        Video Games  Turtle Beach Stealth 600 Wireless Surround Sou...
# ...              ...                                                ...
# 164293   Video Games                     You Don't Know Jack - Xbox 360
# 164294   Video Games                        Wheel of Fortune - Xbox 360
# 164295   Video Games                  Press Your Luck 2010 Edition - PC
# 164296   Video Games     Tzou AC Power Adapter for Nintendo Wii Console
# 164297   Video Games   Rocksmith 2014 Edition - PC/Mac (Cable Included)
#
#                                               description  \
# 0                                                      []
# 1          [Logitech G402 Hyperion Fury FPS Gaming Mouse]
# 2       [Logitech G433 gaming headset is the premium a...
# 3       [Play anywhere with the Razer Wolverine Ultima...
# 4       [The Turtle Beach Stealth 600 is the latest wi...
# ...                                                   ...
# 164293  [Product Description, The award-winning You Do...
# 164294  [Spin the wheel along with Pat Sajak and Vanna...
# 164295  [Collect "spins by answering trivia questions,...
# 164296  [Did you misplace or destroy the AC power adap...
# 164297  [Product Description, PC System Requirements, ...
#
#                                                categories   price  \
# 0       [Video Games, Legacy Systems, Nintendo Systems...    None
# 1             [Video Games, PC, Accessories, Gaming Mice]    None
# 2          [Video Games, Xbox One, Accessories, Headsets]   44.99
# 3             [Video Games, PC, Accessories, Controllers]   64.98
# 4       [Video Games, PlayStation 4, Accessories, Head...  168.75
# ...                                                   ...     ...
# 164293  [Video Games, Legacy Systems, Xbox Systems, Xb...   20.55
# 164294  [Video Games, Legacy Systems, Xbox Systems, Xb...   24.99
# 164295                           [Video Games, PC, Games]   135.0
# 164296  [Video Games, Legacy Systems, Nintendo Systems...    None
# 164297                                  [Video Games, PC]   84.95
#
#                                                    images
# 0       {'hi_res': ['https://m.media-amazon.com/images...
# 1       {'hi_res': ['https://m.media-amazon.com/images...
# 2       {'hi_res': ['https://m.media-amazon.com/images...
# 3       {'hi_res': ['https://m.media-amazon.com/images...
# 4       {'hi_res': ['https://m.media-amazon.com/images...
# ...                                                   ...
# 164293  {'hi_res': ['https://m.media-amazon.com/images...
# 164294  {'hi_res': [None, 'https://m.media-amazon.com/...
# 164295  {'hi_res': [None, 'https://m.media-amazon.com/...
# 164296  {'hi_res': ['https://m.media-amazon.com/images...
# 164297  {'hi_res': ['https://m.media-amazon.com/images...
#
# [164298 rows x 10 columns]

# %%
train_features_df.dtypes
# Out:
# user_id           object
# parent_asin       object
# rating           float64
# timestamp          int64
# main_category     object
# title             object
# description       object
# categories        object
# price             object
# images            object
# dtype: object

# %%
full_df = (
    pd.concat(
        [train_features_df, val_features_df],
        axis=0,
    )
    .assign(
        description=lambda df: df["description"].apply(list),
        categories=lambda df: df["categories"].apply(list),
    )
    .pipe(parse_dt)
    .pipe(handle_dtypes)
)
full_df
# Out:
#                           user_id parent_asin  rating               timestamp  \
# 0    AHATA6X6MYTC3VNBFJ3WIYVK257A  B0050SVNZ8     4.0 2011-11-21 14:27:44.000
# 1    AHATA6X6MYTC3VNBFJ3WIYVK257A  B00LZVNWIA     4.0 2014-08-17 00:00:06.000
# 2    AHATA6X6MYTC3VNBFJ3WIYVK257A  B0BH98D8GL     5.0 2017-11-26 15:02:34.100
# 3    AHATA6X6MYTC3VNBFJ3WIYVK257A  B074RNL1RX     5.0 2017-11-27 03:26:14.174
# 4    AHATA6X6MYTC3VNBFJ3WIYVK257A  B089QYP649     5.0 2018-07-08 23:33:40.696
# ..                            ...         ...     ...                     ...
# 957  AE3NRCMFIBBA2XVODR47YYNLKRDA  B001EYUQC8     5.0 2021-11-13 09:59:46.634
# 958  AEV5TZDZQEP24PM3SZ7SNV4TR26Q  B01N3ASPNV     5.0 2022-06-17 07:42:54.083
# 959  AELRDP5MCGSCANM6GWUXAMBN75LQ  B009AGXH64     5.0 2022-06-03 18:23:36.536
# 960  AHERXKLMQLGPQLW4ZLKD4IRLMZAA  B07M6RVMPJ     5.0 2021-11-27 00:36:11.015
# 961  AG25CXR2DXZV62WNVA46GAF2BL2Q  B08LT6PT1X     5.0 2021-12-04 19:45:39.059
#
#        main_category                                              title  \
# 0        Video Games  Amazon Basics Carrying Case for Nintendo - New...
# 1          Computers       Logitech G402 Hyperion Fury FPS Gaming Mouse
# 2          Computers  Logitech G433 7.1 Wired Gaming Headset with DT...
# 3        Video Games  Razer Wolverine Ultimate Officially Licensed X...
# 4        Video Games  Turtle Beach Stealth 600 Wireless Surround Sou...
# ..               ...                                                ...
# 957      Video Games              007 Quantum Of Solace - Playstation 3
# 958  All Electronics  amFilm Tempered Glass Screen Protector for Nin...
# 959      Video Games     Nintendo Wii U Console - 32GB Black Deluxe Set
# 960      Video Games            Mario Party: The Top 100 - Nintendo 3DS
# 961      Video Games    Xbox Elite Wireless Controller Series 2 – Black
#
#                                            description  \
# 0                                                   []
# 1       [Logitech G402 Hyperion Fury FPS Gaming Mouse]
# 2    [Logitech G433 gaming headset is the premium a...
# 3    [Play anywhere with the Razer Wolverine Ultima...
# 4    [The Turtle Beach Stealth 600 is the latest wi...
# ..                                                 ...
# 957  [James Bond is back to settle the score in Qua...
# 958                                                 []
# 959  [Wii U is the next great gaming console from N...
# 960  [Ever partied with Mario? stuffed mouthfuls of...
# 961  [Experience the Xbox Elite Wireless Controller...
#
#                                             categories   price  \
# 0    [Video Games, Legacy Systems, Nintendo Systems...    None
# 1          [Video Games, PC, Accessories, Gaming Mice]    None
# 2       [Video Games, Xbox One, Accessories, Headsets]   44.99
# 3          [Video Games, PC, Accessories, Controllers]   64.98
# 4    [Video Games, PlayStation 4, Accessories, Head...  168.75
# ..                                                 ...     ...
# 957  [Video Games, Legacy Systems, PlayStation Syst...   44.49
# 958  [Video Games, Nintendo Switch, Accessories, Fa...    8.91
# 959  [Video Games, Legacy Systems, Nintendo Systems...  199.99
# 960  [Video Games, Legacy Systems, Nintendo Systems...   48.99
# 961  [Video Games, Xbox One, Accessories, Controllers]  144.99
#
#                                                 images
# 0    {'hi_res': ['https://m.media-amazon.com/images...
# 1    {'hi_res': ['https://m.media-amazon.com/images...
# 2    {'hi_res': ['https://m.media-amazon.com/images...
# 3    {'hi_res': ['https://m.media-amazon.com/images...
# 4    {'hi_res': ['https://m.media-amazon.com/images...
# ..                                                 ...
# 957  {'hi_res': ['https://m.media-amazon.com/images...
# 958  {'hi_res': ['https://m.media-amazon.com/images...
# 959  {'hi_res': [None, None, None], 'large': ['http...
# 960  {'hi_res': ['https://m.media-amazon.com/images...
# 961  {'hi_res': ['https://m.media-amazon.com/images...
#
# [165260 rows x 10 columns]

# %%
holdout_date = (
    full_df["timestamp"].max() - pd.to_timedelta(args.num_days_holdout, unit="d")
).strftime("%Y-%m-%d")
logger.info(f"{holdout_date=}")
to_insert_df = full_df.loc[lambda df: df["timestamp"].lt(holdout_date)]
holdout_df = full_df.loc[lambda df: df["timestamp"].ge(holdout_date)]
# Out:
# 2025-11-15 17:52:17.714 | INFO     | __main__:<module>:4 - holdout_date='2022-06-16'

# %%
to_insert_df
# Out:
#                           user_id parent_asin  rating               timestamp  \
# 0    AHATA6X6MYTC3VNBFJ3WIYVK257A  B0050SVNZ8     4.0 2011-11-21 14:27:44.000
# 1    AHATA6X6MYTC3VNBFJ3WIYVK257A  B00LZVNWIA     4.0 2014-08-17 00:00:06.000
# 2    AHATA6X6MYTC3VNBFJ3WIYVK257A  B0BH98D8GL     5.0 2017-11-26 15:02:34.100
# 3    AHATA6X6MYTC3VNBFJ3WIYVK257A  B074RNL1RX     5.0 2017-11-27 03:26:14.174
# 4    AHATA6X6MYTC3VNBFJ3WIYVK257A  B089QYP649     5.0 2018-07-08 23:33:40.696
# ..                            ...         ...     ...                     ...
# 956  AE6ESC5VTUU7A4XGTN4VWTQJRMLQ  B08LT6PT1X     5.0 2021-09-24 03:38:21.868
# 957  AE3NRCMFIBBA2XVODR47YYNLKRDA  B001EYUQC8     5.0 2021-11-13 09:59:46.634
# 959  AELRDP5MCGSCANM6GWUXAMBN75LQ  B009AGXH64     5.0 2022-06-03 18:23:36.536
# 960  AHERXKLMQLGPQLW4ZLKD4IRLMZAA  B07M6RVMPJ     5.0 2021-11-27 00:36:11.015
# 961  AG25CXR2DXZV62WNVA46GAF2BL2Q  B08LT6PT1X     5.0 2021-12-04 19:45:39.059
#
#     main_category                                              title  \
# 0     Video Games  Amazon Basics Carrying Case for Nintendo - New...
# 1       Computers       Logitech G402 Hyperion Fury FPS Gaming Mouse
# 2       Computers  Logitech G433 7.1 Wired Gaming Headset with DT...
# 3     Video Games  Razer Wolverine Ultimate Officially Licensed X...
# 4     Video Games  Turtle Beach Stealth 600 Wireless Surround Sou...
# ..            ...                                                ...
# 956   Video Games    Xbox Elite Wireless Controller Series 2 – Black
# 957   Video Games              007 Quantum Of Solace - Playstation 3
# 959   Video Games     Nintendo Wii U Console - 32GB Black Deluxe Set
# 960   Video Games            Mario Party: The Top 100 - Nintendo 3DS
# 961   Video Games    Xbox Elite Wireless Controller Series 2 – Black
#
#                                            description  \
# 0                                                   []
# 1       [Logitech G402 Hyperion Fury FPS Gaming Mouse]
# 2    [Logitech G433 gaming headset is the premium a...
# 3    [Play anywhere with the Razer Wolverine Ultima...
# 4    [The Turtle Beach Stealth 600 is the latest wi...
# ..                                                 ...
# 956  [Experience the Xbox Elite Wireless Controller...
# 957  [James Bond is back to settle the score in Qua...
# 959  [Wii U is the next great gaming console from N...
# 960  [Ever partied with Mario? stuffed mouthfuls of...
# 961  [Experience the Xbox Elite Wireless Controller...
#
#                                             categories   price  \
# 0    [Video Games, Legacy Systems, Nintendo Systems...    None
# 1          [Video Games, PC, Accessories, Gaming Mice]    None
# 2       [Video Games, Xbox One, Accessories, Headsets]   44.99
# 3          [Video Games, PC, Accessories, Controllers]   64.98
# 4    [Video Games, PlayStation 4, Accessories, Head...  168.75
# ..                                                 ...     ...
# 956  [Video Games, Xbox One, Accessories, Controllers]  144.99
# 957  [Video Games, Legacy Systems, PlayStation Syst...   44.49
# 959  [Video Games, Legacy Systems, Nintendo Systems...  199.99
# 960  [Video Games, Legacy Systems, Nintendo Systems...   48.99
# 961  [Video Games, Xbox One, Accessories, Controllers]  144.99
#
#                                                 images
# 0    {'hi_res': ['https://m.media-amazon.com/images...
# 1    {'hi_res': ['https://m.media-amazon.com/images...
# 2    {'hi_res': ['https://m.media-amazon.com/images...
# 3    {'hi_res': ['https://m.media-amazon.com/images...
# 4    {'hi_res': ['https://m.media-amazon.com/images...
# ..                                                 ...
# 956  {'hi_res': ['https://m.media-amazon.com/images...
# 957  {'hi_res': ['https://m.media-amazon.com/images...
# 959  {'hi_res': [None, None, None], 'large': ['http...
# 960  {'hi_res': ['https://m.media-amazon.com/images...
# 961  {'hi_res': ['https://m.media-amazon.com/images...
#
# [165186 rows x 10 columns]

# %%
holdout_df
# Out:
#                           user_id parent_asin  rating               timestamp  \
# 6    AHLBT2RDWYQWN5O2XNBNX2JPWVZA  B08NYV2VLS     4.0 2022-07-08 18:26:28.360
# 7    AHLBT2RDWYQWN5O2XNBNX2JPWVZA  B00KWIYPZG     5.0 2022-07-08 18:27:49.294
# 12   AF5NKVKUZGRPBR7HAYYDUS25RGRQ  B0BKRXQ5GL     3.0 2022-07-06 12:14:32.366
# 25   AGGRGJRYYYWAL7V5M4RG4VFKL3HA  B07BGYLS1L     5.0 2022-06-25 20:06:42.077
# 60   AEKEN3WITS4ZEJ7ZIISGJDZYJB3Q  B0BH1ZL3G9     5.0 2022-06-16 19:54:29.703
# ..                            ...         ...     ...                     ...
# 877  AETZPD7JKD42GBVYXBYPGOY4NF6Q  B09B35J159     4.0 2022-07-08 19:10:11.311
# 878  AETZPD7JKD42GBVYXBYPGOY4NF6Q  B09QVJDVHN     5.0 2022-07-08 19:13:28.232
# 926  AEVNAGOLV5MAGEPCCTT6ADCGNFWA  B08DF248LD     3.0 2022-07-08 05:07:25.394
# 944  AGMNHX4YCSY3BJTLDALLPD5XEYTA  B07WSHTJ48     3.0 2022-07-01 00:34:15.608
# 958  AEV5TZDZQEP24PM3SZ7SNV4TR26Q  B01N3ASPNV     5.0 2022-06-17 07:42:54.083
#
#        main_category                                              title  \
# 6        Video Games     Story of Seasons: Trio of Towns - Nintendo 3DS
# 7        Video Games                                 Fantasy Life - 3DS
# 12         Computers  Logitech G Logitech G935 Over Ear Wireless Hea...
# 25       Video Games               Shadow of the Tomb Raider - Xbox One
# 60         Computers  Hipshotdot PRO Color and Brightness Control Do...
# ..               ...                                                ...
# 877        Computers  Razer Basilisk Ultimate HyperSpeed Wireless Ga...
# 878        Computers  Redragon K552 Mechanical Gaming Keyboard RGB L...
# 926      Video Games       Xbox Core Wireless Controller – Carbon Black
# 944        Computers  Redragon S101 Gaming Keyboard, M601 Mouse, RGB...
# 958  All Electronics  amFilm Tempered Glass Screen Protector for Nin...
#
#                                            description  \
# 6    [STORY OF SEASONS: Trio of Towns is a fresh ne...
# 7    [Embark on a Journey that Lets You Build Your ...
# 12   [Logitech G935 Wireless DTS:X 7.1 Surround Sou...
# 25   [Experience Lara croft's defining moment as sh...
# 60   [The HipShotDot is the gaming industry’s first...
# ..                                                 ...
# 877  [With a high-speed transmission, extremely low...
# 878  [Redragon K552 Pro KUMARA 87 Key RGB LED Backl...
# 926  [Experience the modernized design of the Xbox ...
# 944                                                 []
# 958                                                 []
#
#                                             categories   price  \
# 6    [Video Games, Legacy Systems, Nintendo Systems...    None
# 7    [Video Games, Legacy Systems, Nintendo Systems...   96.65
# 12            [Video Games, PC, Accessories, Headsets]  153.98
# 25                      [Video Games, Xbox One, Games]    14.8
# 60   [Video Games, PC, Accessories, Controllers, Ga...   22.99
# ..                                                 ...     ...
# 877        [Video Games, PC, Accessories, Gaming Mice]    None
# 878   [Video Games, PC, Accessories, Gaming Keyboards]   48.99
# 926                                                 []    45.5
# 944   [Video Games, PC, Accessories, Gaming Keyboards]   39.99
# 958  [Video Games, Nintendo Switch, Accessories, Fa...    8.91
#
#                                                 images
# 6    {'hi_res': ['https://m.media-amazon.com/images...
# 7    {'hi_res': ['https://m.media-amazon.com/images...
# 12   {'hi_res': [None, 'https://m.media-amazon.com/...
# 25   {'hi_res': ['https://m.media-amazon.com/images...
# 60   {'hi_res': ['https://m.media-amazon.com/images...
# ..                                                 ...
# 877  {'hi_res': ['https://m.media-amazon.com/images...
# 878  {'hi_res': ['https://m.media-amazon.com/images...
# 926  {'hi_res': ['https://m.media-amazon.com/images...
# 944  {'hi_res': ['https://m.media-amazon.com/images...
# 958  {'hi_res': ['https://m.media-amazon.com/images...
#
# [74 rows x 10 columns]

# %% [markdown]
# # Insert postgres

# %%
# PostgreSQL connection details
username = os.getenv("POSTGRES_USER")
password = os.getenv("POSTGRES_PASSWORD")
host = os.getenv("POSTGRES_HOST")
port = os.getenv("POSTGRES_PORT")
database = os.getenv("POSTGRES_DB")
schema = os.getenv("POSTGRES_OLTP_SCHEMA")

# Create a connection string and engine outside the function
connection_string = f"postgresql://{username}:{password}@{host}:{port}/{database}"
engine = create_engine(connection_string)

# %%
# Check and drop existing table to avoid schema conflicts
try:
    with engine.connect() as conn:
        conn.execute(f"DROP TABLE IF EXISTS {schema}.{args.table_name}")
        conn.commit()
    print(f"Dropped existing table {schema}.{args.table_name}")
except Exception as e:
    print(f"No existing table to drop or error: {e}")
# Out:
# No existing table to drop or error: 'Connection' object has no attribute 'commit'
# /tmp/ipykernel_2961/2037101143.py:4: RemovedIn20Warning: Deprecated API features detected! These feature(s) are not compatible with SQLAlchemy 2.0. To prevent incompatible upgrades prior to updating applications, ensure requirements files are pinned to "sqlalchemy<2.0". Set environment variable SQLALCHEMY_WARN_20=1 to show all deprecation warnings.  Set environment variable SQLALCHEMY_SILENCE_UBER_WARNING=1 to silence this message. (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   conn.execute(f"DROP TABLE IF EXISTS {schema}.{args.table_name}")

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
to_insert_df.to_sql(
    args.table_name, engine, if_exists="append", index=False, schema=schema
)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File /mnt/d/projects/recsys/backend/.venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1890, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1889     if not evt_handled:
# -> 1890         self.dialect.do_executemany(
#    1891             cursor, statement, parameters, context
#    1892         )
#    1893 elif not parameters and context.no_parameters:
#
# File /mnt/d/projects/recsys/backend/.venv/lib/python3.11/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py:982, in PGDialect_psycopg2.do_executemany(self, cursor, statement, parameters, context)
#     981     xtras = self._psycopg2_extras()
# --> 982     context._psycopg2_fetched_rows = xtras.execute_values(
#     983         cursor,
#     984         statement,
#     985         parameters,
#     986         template=executemany_values,
#     987         fetch=bool(context.compiled.returning),
#     988         **kwargs
#     989     )
#     991 elif self.executemany_mode & EXECUTEMANY_BATCH:
#
# File /mnt/d/projects/recsys/backend/.venv/lib/python3.11/site-packages/psycopg2/extras.py:1296, in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1295 for args in page:
# -> 1296     parts.append(cur.mogrify(template, args))
#    1297     parts.append(b',')
#
# ProgrammingError: can't adapt type 'dict'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 to_insert_df.to_sql(
#       2     args.table_name, engine, if_exists="append", index=False, schema=schema
#       3 )
#
# File /mnt/d/projects/recsys/backend/.venv/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File /mnt/d/projects/recsys/backend/.venv/lib/python3.11/site-packages/pandas/core/generic.py:3008, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2813 """
#    2814 Write records stored in a DataFrame to a SQL database.
#    2815
#    (...)   3004 [(1,), (None,), (2,)]
#    3005 """  # noqa: E501
#    3006 from pandas.io import sql
# -> 3008 return sql.to_sql(
#    3009     self,
#    3010     name,
#    3011     con,
#    3012     schema=schema,
#    3013     if_exists=if_exists,
#    3014     index=index,
#    3015     index_label=index_label,
#    3016     chunksize=chunksize,
#    3017     dtype=dtype,
#    3018     method=method,
#    3019 )
#
# File /mnt/d/projects/recsys/backend/.venv/lib/python3.11/site-packages/pandas/io/sql.py:788, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     783     raise NotImplementedError(
#     784         "'frame' argument should be either a Series or a DataFrame"
#     785     )
#     787 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 788     return pandas_sql.to_sql(
#     789         frame,
#     790         name,
#     791         if_exists=if_exists,
#     792         index=index,
#     793         index_label=index_label,
#     794         schema=schema,
#     795         chunksize=chunksize,
#     796         dtype=dtype,
#     797         method=method,
#     798         engine=engine,
#     799         **engine_kwargs,
#     800     )
#
# File /mnt/d/projects/recsys/backend/.venv/lib/python3.11/site-packages/pandas/io/sql.py:1958, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1946 sql_engine = get_engine(engine)
#    1948 table = self.prep_table(
#    1949     frame=frame,
#    1950     name=name,
#    (...)   1955     dtype=dtype,
#    1956 )
# -> 1958 total_inserted = sql_engine.insert_records(
#    1959     table=table,
#    1960     con=self.con,
#    1961     frame=frame,
#    1962     name=name,
#    1963     index=index,
#    1964     schema=schema,
#    1965     chunksize=chunksize,
#    1966     method=method,
#    1967     **engine_kwargs,
#    1968 )
#    1970 self.check_case_sensitive(name=name, schema=schema)
#    1971 return total_inserted
#
# File /mnt/d/projects/recsys/backend/.venv/lib/python3.11/site-packages/pandas/io/sql.py:1507, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1505 if re.search(msg, err_text):
#    1506     raise ValueError("inf cannot be used with MySQL") from err
# -> 1507 raise err
#
# File /mnt/d/projects/recsys/backend/.venv/lib/python3.11/site-packages/pandas/io/sql.py:1498, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1495 from sqlalchemy import exc
#    1497 try:
# -> 1498     return table.insert(chunksize=chunksize, method=method)
#    1499 except exc.StatementError as err:
#    1500     # GH34431
#    1501     # https://stackoverflow.com/a/67358288/6067848
#    1502     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1503     )|inf can not be used with MySQL"""
#
# File /mnt/d/projects/recsys/backend/.venv/lib/python3.11/site-packages/pandas/io/sql.py:1059, in SQLTable.insert(self, chunksize, method)
#    1056     break
#    1058 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1059 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1060 # GH 46891
#    1061 if num_inserted is not None:
#
# File /mnt/d/projects/recsys/backend/.venv/lib/python3.11/site-packages/pandas/io/sql.py:951, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     939 """
#     940 Execute SQL statement inserting data
#     941
#    (...)    948    Each item contains a list of values to be inserted
#     949 """
#     950 data = [dict(zip(keys, row)) for row in data_iter]
# --> 951 result = conn.execute(self.table.insert(), data)
#     952 return result.rowcount
#
# File /mnt/d/projects/recsys/backend/.venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1385, in Connection.execute(self, statement, *multiparams, **params)
#    1381     util.raise_(
#    1382         exc.ObjectNotExecutableError(statement), replace_context=err
#    1383     )
#    1384 else:
# -> 1385     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File /mnt/d/projects/recsys/backend/.venv/lib/python3.11/site-packages/sqlalchemy/sql/elements.py:334, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     330 def _execute_on_connection(
#     331     self, connection, multiparams, params, execution_options, _force=False
#     332 ):
#     333     if _force or self.supports_execution:
# --> 334         return connection._execute_clauseelement(
#     335             self, multiparams, params, execution_options
#     336         )
#     337     else:
#     338         raise exc.ObjectNotExecutableError(self)
#
# File /mnt/d/projects/recsys/backend/.venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1577, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1565 compiled_cache = execution_options.get(
#    1566     "compiled_cache", self.engine._compiled_cache
#    1567 )
#    1569 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1570     dialect=dialect,
#    1571     compiled_cache=compiled_cache,
#    (...)   1575     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1576 )
# -> 1577 ret = self._execute_context(
#    1578     dialect,
#    1579     dialect.execution_ctx_cls._init_compiled,
#    1580     compiled_sql,
#    1581     distilled_params,
#    1582     execution_options,
#    1583     compiled_sql,
#    1584     distilled_params,
#    1585     elem,
#    1586     extracted_params,
#    1587     cache_hit=cache_hit,
#    1588 )
#    1589 if has_events:
#    1590     self.dispatch.after_execute(
#    1591         self,
#    1592         elem,
#    (...)   1596         ret,
#    1597     )
#
# File /mnt/d/projects/recsys/backend/.venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1953, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1950             branched.close()
#    1952 except BaseException as e:
# -> 1953     self._handle_dbapi_exception(
#    1954         e, statement, parameters, cursor, context
#    1955     )
#    1957 return result
#
# File /mnt/d/projects/recsys/backend/.venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2134, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2132     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2133 elif should_wrap:
# -> 2134     util.raise_(
#    2135         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2136     )
#    2137 else:
#    2138     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File /mnt/d/projects/recsys/backend/.venv/lib/python3.11/site-packages/sqlalchemy/util/compat.py:211, in raise_(***failed resolving arguments***)
#     208     exception.__cause__ = replace_context
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#     216     del exception, replace_context, from_, with_traceback
#
# File /mnt/d/projects/recsys/backend/.venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1890, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1888                 break
#    1889     if not evt_handled:
# -> 1890         self.dialect.do_executemany(
#    1891             cursor, statement, parameters, context
#    1892         )
#    1893 elif not parameters and context.no_parameters:
#    1894     if self.dialect._has_events:
#
# File /mnt/d/projects/recsys/backend/.venv/lib/python3.11/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py:982, in PGDialect_psycopg2.do_executemany(self, cursor, statement, parameters, context)
#     980         kwargs = {}
#     981     xtras = self._psycopg2_extras()
# --> 982     context._psycopg2_fetched_rows = xtras.execute_values(
#     983         cursor,
#     984         statement,
#     985         parameters,
#     986         template=executemany_values,
#     987         fetch=bool(context.compiled.returning),
#     988         **kwargs
#     989     )
#     991 elif self.executemany_mode & EXECUTEMANY_BATCH:
#     992     if self.executemany_batch_page_size:
#
# File /mnt/d/projects/recsys/backend/.venv/lib/python3.11/site-packages/psycopg2/extras.py:1296, in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1294 parts = pre[:]
#    1295 for args in page:
# -> 1296     parts.append(cur.mogrify(template, args))
#    1297     parts.append(b',')
#    1298 parts[-1:] = post
#
# ProgrammingError: (psycopg2.ProgrammingError) can't adapt type 'dict'
# [SQL: INSERT INTO oltp.amz_review_rating_raw (user_id, parent_asin, rating, timestamp, main_category, title, description, categories, price, images) VALUES (%(user_id)s, %(parent_asin)s, %(rating)s, %(timestamp)s, %(main_category)s, %(title)s, %(description)s, %(categories)s, %(price)s, %(images)s)]
# [parameters: ({'user_id': 'AHATA6X6MYTC3VNBFJ3WIYVK257A', 'parent_asin': 'B0050SVNZ8', 'rating': 4.0, 'timestamp': datetime.datetime(2011, 11, 21, 14, 27, 44), 'main_category': 'Video Games', 'title': 'Amazon Basics Carrying Case for Nintendo - New 3DS XL, 3DS XL - Black (Officially Licensed by Nintendo)', 'description': [], 'categories': ['Video Games', 'Legacy Systems', 'Nintendo Systems', 'Nintendo DS', 'Accessories', 'Cases & Storage'], 'price': 'None', 'images': {'hi_res': array(['https://m.media-amazon.com/images/I/81x+m9hzBxL._SL1500_.jpg',
#        'https://m.media-amazon.com/images/I/91mU2h9i8qL._SL1500_.jpg ... (1132 characters truncated) ... s/I/418bS0nVUKL._SX38_SY50_CR,0,0,38,50_.jpg'],
#       dtype=object), 'variant': array(['MAIN', 'PT01', 'PT02', 'PT03', 'PT04', 'PT15'], dtype=object)}}, {'user_id': 'AHATA6X6MYTC3VNBFJ3WIYVK257A', 'parent_asin': 'B00LZVNWIA', 'rating': 4.0, 'timestamp': datetime.datetime(2014, 8, 17, 0, 0, 6), 'main_category': 'Computers', 'title': 'Logitech G402 Hyperion Fury FPS Gaming Mouse', 'description': ['Logitech G402 Hyperion Fury FPS Gaming Mouse'], 'categories': ['Video Games', 'PC', 'Accessories', 'Gaming Mice'], 'price': 'None', 'images': {'hi_res': array(['https://m.media-amazon.com/images/I/71GeWA096AL._AC_SL1500_.jpg',
#        'https://m.media-amazon.com/images/I/91svIRFiCJL._AC_SL150 ... (1399 characters truncated) ... C8GAGCwL._AC_US40_.jpg'],
#       dtype=object), 'variant': array(['MAIN', 'PT01', 'PT02', 'PT03', 'PT04', 'PT05', 'PT06', 'PT07'],
#       dtype=object)}}, {'user_id': 'AHATA6X6MYTC3VNBFJ3WIYVK257A', 'parent_asin': 'B0BH98D8GL', 'rating': 5.0, 'timestamp': datetime.datetime(2017, 11, 26, 15, 2, 34, 100000), 'main_category': 'Computers', 'title': 'Logitech G433 7.1 Wired Gaming Headset with DTS Headphone: X 7.1 Surround for PC, PS4, PS4 PRO, Xbox One, Xbox One S, Nintendo Switch – Triple Black', 'description': ['Logitech G433 gaming headset is the premium audio experience designed for life in and out of the game. Patent-pending Pro-G audio drivers smoothly d ... (8 characters truncated) ... xplosive DTS Headphone: X 7.1 surround sound. Vibrant color choices in a lightweight, stain-resistant fabric make G433 as wearable as your sneakers.'], 'categories': ['Video Games', 'Xbox One', 'Accessories', 'Headsets'], 'price': '44.99', 'images': {'hi_res': array(['https://m.media-amazon.com/images/I/71NpexEi3pL._AC_SL1500_.jpg',
#        'https://m.media-amazon.com/images/I/718+ZfChb6L._AC_SL150 ... (2266 characters truncated) ...
#       dtype=object), 'variant': array(['MAIN', 'PT01', 'PT02', 'PT03', 'PT04', 'PT05', 'PT06', 'PT07',
#        'PT08', 'PT09', 'PT10'], dtype=object)}}, {'user_id': 'AHATA6X6MYTC3VNBFJ3WIYVK257A', 'parent_asin': 'B074RNL1RX', 'rating': 5.0, 'timestamp': datetime.datetime(2017, 11, 27, 3, 26, 14, 174000), 'main_category': 'Video Games', 'title': 'Razer Wolverine Ultimate Officially Licensed Xbox One Controller: 6 Remappable Buttons and Triggers - Interchangeable Thumbsticks and D-Pad - For PC, Xbox One, Xbox Series X & S - Black', 'description': ['Play anywhere with the Razer Wolverine Ultimate, the most customizable controller for competitive play both on Xbox One & PC. From interchangeable t ... (210 characters truncated) ... Chroma lighting, allowing you to further personalize your controller or enjoy an even more immersive experience with game-integrated smart lighting.'], 'categories': ['Video Games', 'PC', 'Accessories', 'Controllers'], 'price': '64.98', 'images': {'hi_res': array(['https://m.media-amazon.com/images/I/81kKfnnHeuL._SL1500_.jpg',
#        'https://m.media-amazon.com/images/I/71pFgFkqWAL._SL1500_.jpg ... (1430 characters truncated) ... L._SX38_SY50_CR,0,0,38,50_.jpg'],
#       dtype=object), 'variant': array(['MAIN', 'PT01', 'PT02', 'PT03', 'PT04', 'PT05', 'PT06'],
#       dtype=object)}}, {'user_id': 'AHATA6X6MYTC3VNBFJ3WIYVK257A', 'parent_asin': 'B089QYP649', 'rating': 5.0, 'timestamp': datetime.datetime(2018, 7, 8, 23, 33, 40, 696000), 'main_category': 'Video Games', 'title': 'Turtle Beach Stealth 600 Wireless Surround Sound Gaming Headset for PlayStation 5 and PlayStation 4', 'description': ['The Turtle Beach Stealth 600 is the latest wireless surround sound gaming headset for PS5 & PS4. Debuting an all-new modern style, the Stealth 600 d ... (587 characters truncated) ...  that PS4 headsets will work on PS5. Turtle Beach anticipates the Stealth 600 will be compatible with PS5 and will confirm once testing is complete.'], 'categories': ['Video Games', 'PlayStation 4', 'Accessories', 'Headsets'], 'price': '168.75', 'images': {'hi_res': array(['https://m.media-amazon.com/images/I/61zUeA1-wNL._SL1360_.jpg',
#        'https://m.media-amazon.com/images/I/71-kMXZhVhL._SL1500_.jpg ... (2571 characters truncated) ... type=object), 'variant': array(['MAIN', 'BACK', 'PT01', 'PT02', 'PT03', 'PT04', 'PT05', 'PT08',
#        'PT09', 'PT10', 'PT11', 'GLMR'], dtype=object)}}, {'user_id': 'AHATA6X6MYTC3VNBFJ3WIYVK257A', 'parent_asin': 'B07DHNX18W', 'rating': 4.0, 'timestamp': datetime.datetime(2020, 11, 2, 20, 18, 55, 46000), 'main_category': 'Computers', 'title': 'Razer Huntsman Elite Gaming Keyboard: Fast Keyboard Switches - Clicky Optical Switches - Chroma RGB Lighting - Magnetic Plush Wrist Rest - Dedicated Media Keys & Dial - Classic Black', 'description': ["Introduces the new Razer Opto-Mechanical switch, utilizing Optical technology for unmatched speed, and a key stabilizer Bar so every keypress is pre ... (220 characters truncated) ... ccess to functions. Personalize settings with hybrid on-board memory and cloud storage. Comes with an ergonomic wrist rest for long-lasting comfort."], 'categories': ['Video Games', 'PC', 'Accessories', 'Gaming Keyboards'], 'price': '219.99', 'images': {'hi_res': array(['https://m.media-amazon.com/images/I/81Vtb-0K3-L._AC_SL1500_.jpg',
#        'https://m.media-amazon.com/images/I/71a2VEe0ncL._AC_SL150 ... (1381 characters truncated) ... es/I/51+RuI0-fyL._AC_US40_.jpg'],
#       dtype=object), 'variant': array(['MAIN', 'PT02', 'PT03', 'PT04', 'PT05', 'PT06', 'AW02'],
#       dtype=object)}}, {'user_id': 'AHV6QCNBJNSGLATP56JAWJ3C4G2A', 'parent_asin': 'B019WRM1IA', 'rating': 5.0, 'timestamp': datetime.datetime(2016, 1, 3, 22, 31, 49), 'main_category': 'All Electronics', 'title': 'Microsoft Xbox 360 Wired Controller for Windows & Xbox 360 Console', 'description': ['Product Description', 'Precisely what you need for PC and Xbox gaming. Play with confidence with this responsive, ergonomic controller. It works on  ... (753 characters truncated) ... stable vibration feedback for a personalized gaming experience', 'Works with most Windows Vista-based PCS', 'Works with most Windows Vista-based PCS'], 'categories': ['Video Games', 'Legacy Systems', 'Xbox Systems', 'Xbox 360', 'Accessories', 'Controllers', 'Gamepads & Standard Controllers'], 'price': '67.83', 'images': {'hi_res': array(['https://m.media-amazon.com/images/I/61ctfFQjHlL._AC_SL1000_.jpg',
#        'https://m.media-amazon.com/images/I/6165IiVbT2L._AC_SL100 ... (270 characters truncated) ... .jpg',
#        'https://m.media-amazon.com/images/I/418bAnKudeL._AC_US40_.jpg'],
#       dtype=object), 'variant': array(['MAIN', 'PT01'], dtype=object)}}, {'user_id': 'AHV6QCNBJNSGLATP56JAWJ3C4G2A', 'parent_asin': 'B08DHTZNNF', 'rating': 4.0, 'timestamp': datetime.datetime(2018, 9, 28, 11, 48, 32, 132000), 'main_category': 'Computers', 'title': 'Razer Mamba Elite Wired Gaming Mouse: 16,000 DPI Optical Sensor - Chroma RGB Lighting - 9 Programmable Buttons - Mechanical Switches', 'description': ['The Razer Mamba Elite features our acclaimed Razer 5G advanced optical sensor with true 16, 000 DPI and Razer Mechanical mouse switches with extende ... (258 characters truncated) ...  of your mouse, customize with preset lighting effects or create your own From 16.8 million color options. Hybrid on-board memory and cloud storage.'], 'categories': ['Video Games', 'Legacy Systems', 'PlayStation Systems', 'PlayStation', 'Accessories'], 'price': '36.95', 'images': {'hi_res': array(['https://m.media-amazon.com/images/I/61YTpIudkeL._AC_SL1499_.jpg',
#        'https://m.media-amazon.com/images/I/511slrd6cEL._AC_SL145 ... (1602 characters truncated) ... E+aw4wTL._AC_US40_.jpg'],
#       dtype=object), 'variant': array(['MAIN', 'PT01', 'PT02', 'PT03', 'PT04', 'PT05', 'PT06', 'PT07'],
#       dtype=object)}}  ... displaying 10 of 165186 total bound parameter sets ...  {'user_id': 'AHERXKLMQLGPQLW4ZLKD4IRLMZAA', 'parent_asin': 'B07M6RVMPJ', 'rating': 5.0, 'timestamp': datetime.datetime(2021, 11, 27, 0, 36, 11, 15000), 'main_category': 'Video Games', 'title': 'Mario Party: The Top 100 - Nintendo 3DS', 'description': ['Ever partied with Mario? stuffed mouthfuls of pizza? dodge penguins? well, the party is back with the top 100 mini games in Mario party series histo ... (6 characters truncated) ... st your memory, speed, and luck in a variety of game modes. With download play, up to 4 players can party on their own system with just 1 game card!'], 'categories': ['Video Games', 'Legacy Systems', 'Nintendo Systems', 'Nintendo 3DS & 2DS'], 'price': '48.99', 'images': {'hi_res': array(['https://m.media-amazon.com/images/I/61AZX2yGF+L._SL1000_.jpg'],
#       dtype=object), 'large': array(['https://m.media-amazon.com/im ... (56 characters truncated) ... array(['https://m.media-amazon.com/images/I/51GndDHophL._SX38_SY50_CR,0,0,38,50_.jpg'],
#       dtype=object), 'variant': array(['MAIN'], dtype=object)}}, {'user_id': 'AG25CXR2DXZV62WNVA46GAF2BL2Q', 'parent_asin': 'B08LT6PT1X', 'rating': 5.0, 'timestamp': datetime.datetime(2021, 12, 4, 19, 45, 39, 59000), 'main_category': 'Video Games', 'title': 'Xbox Elite Wireless Controller Series 2 – Black', 'description': ['Experience the Xbox Elite Wireless Controller Series 2 featuring adjustable-tension thumbsticks, wrap-around rubberized grip, and shorter hair trigg ... (606 characters truncated) ... amers, the Xbox Elite Wireless Controller Series 2 puts exceptional performance, customization, and durability where it matters most—in your hands.*'], 'categories': ['Video Games', 'Xbox One', 'Accessories', 'Controllers'], 'price': '144.99', 'images': {'hi_res': array(['https://m.media-amazon.com/images/I/71vNw0EbrTL._SL1500_.jpg',
#        'https://m.media-amazon.com/images/I/71wuT1b72QL._SL1500_.jpg ... (1430 characters truncated) ... L._SX38_SY50_CR,0,0,38,50_.jpg'],
#       dtype=object), 'variant': array(['MAIN', 'PT01', 'PT02', 'PT03', 'PT04', 'PT05', 'PT06'],
#       dtype=object)}})]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# # Persist holdout_df

# %%
holdout_df.to_parquet(args.holdout_fp, index=False)

# %%
if os.getenv("S3_ENDPOINT_URL") is not None:
    s3 = init_s3_client()

    bucket_name = "data-recsys"
    train_key = "holdout.parquet"

    s3.upload_file(args.holdout_fp, bucket_name, train_key)

    logger.info(
        f"Local file {os.path.abspath(args.holdout_fp)} uploaded successfully to S3!"
    )
